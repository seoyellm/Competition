# %% [markdown]
# <font size=6><b> 데이콘 Basic 칼로리 소모량 예측 AI 경진대회

# %% [markdown]
# * ref : https://dacon.io/competitions/official/236097/overview/description

# %% [markdown]
# <pre>
# ID : 샘플 별 고유 id
# Exercise_Duration  : 운동 시간(분)
# Body_Temperature(F) : 체온
# BPM : 심박수
# Height(Feet) : 키(피트)
# Height(Remainder_Inches) : 키(피트 계산 후 더해야 할 키)
# Weight(lb) : 몸무게(파운드)
# Weight_Status : 체중 상태
# Gender : 성별
# Age : 나이
# Calories_Burned : 칼로리 소모량(목표 예측값)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

sns.set() 
#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
# plt.rcParams['font.family']= 'Malgun Gothic'  # 한글 처리
# plt.rcParams['axes.unicode_minus'] = False  # -, $ 등등에 표현 특수기호로 버리지 말고 다 써줘라.

# %%
train = pd.read_csv('/content/drive/MyDrive/핀테크_강의/Competition/CAL_CONSUM/datasets/train.csv')
test = pd.read_csv('/content/drive/MyDrive/핀테크_강의/Competition/CAL_CONSUM/datasets/test.csv')
train.head()
# Out:
#            ID  Exercise_Duration  Body_Temperature(F)    BPM  Height(Feet)  \
# 0  TRAIN_0000               26.0                105.6  107.0           5.0
# 1  TRAIN_0001                7.0                103.3   88.0           6.0
# 2  TRAIN_0002                7.0                103.3   86.0           6.0
# 3  TRAIN_0003               17.0                104.0   99.0           5.0
# 4  TRAIN_0004                9.0                102.7   88.0           5.0
#
#    Height(Remainder_Inches)  Weight(lb)  Weight_Status Gender  Age  \
# 0                       9.0       154.3  Normal Weight      F   45
# 1                       6.0       224.9     Overweight      M   50
# 2                       3.0       218.3     Overweight      M   29
# 3                       6.0       147.7  Normal Weight      F   33
# 4                      10.0       169.8  Normal Weight      M   38
#
#    Calories_Burned
# 0            166.0
# 1             33.0
# 2             23.0
# 3             91.0
# 4             32.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        7500 non-null   object
#  1   Exercise_Duration         7500 non-null   float64
#  2   Body_Temperature(F)       7500 non-null   float64
#  3   BPM                       7500 non-null   float64
#  4   Height(Feet)              7500 non-null   float64
#  5   Height(Remainder_Inches)  7500 non-null   float64
#  6   Weight(lb)                7500 non-null   float64
#  7   Weight_Status             7500 non-null   object
#  8   Gender                    7500 non-null   object
#  9   Age                       7500 non-null   int64
#  10  Calories_Burned           7500 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 644.7+ KB

# %% [markdown]
# # EDA

# %% [markdown]
# ## Drop ID

# %%
train = train.drop('ID', axis=1)
test = test.drop('ID', axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Exercise_Duration         7500 non-null   float64
#  1   Body_Temperature(F)       7500 non-null   float64
#  2   BPM                       7500 non-null   float64
#  3   Height(Feet)              7500 non-null   float64
#  4   Height(Remainder_Inches)  7500 non-null   float64
#  5   Weight(lb)                7500 non-null   float64
#  6   Weight_Status             7500 non-null   object
#  7   Gender                    7500 non-null   object
#  8   Age                       7500 non-null   int64
#  9   Calories_Burned           7500 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 586.1+ KB

# %% [markdown]
# ## hist, pair plot

# %%
train.hist()
plt.tight_layout()
plt.show()

# %%
test.hist()
plt.tight_layout()
plt.show()

# %%
sns.pairplot(train)
plt.show()

# %% [markdown]
# ## Height

# %%
train['Height(Inches)'] = train['Height(Feet)']*12
train['Height(Inches)'] = train['Height(Inches)'] + train['Height(Remainder_Inches)']

test['Height(Inches)'] = test['Height(Feet)']*12
test['Height(Inches)'] = test['Height(Inches)'] + test['Height(Remainder_Inches)']

# %%
sns.lmplot(train, x = 'Height(Inches)', y='Calories_Burned')
plt.show()

# %% [markdown]
# ## bmi

# %%
train['Height(m)'] = train['Height(Inches)']/39.37
test['Height(m)'] = test['Height(Inches)']/39.37

train['Weight(kg)'] = train['Weight(lb)']/2.205
test['Weight(kg)'] = test['Weight(lb)']/2.205

# %%
train['bmi'] = train['Weight(kg)']/(train['Height(m)']**2)
test['bmi'] = test['Weight(kg)']/(test['Height(m)']**2)

# %%
sns.lmplot(train, x = 'bmi', y='Calories_Burned')
plt.show()

# %% [markdown]
# ## Weight_Status

# %%
from sklearn.preprocessing import OneHotEncoder

oh = OneHotEncoder(sparse=False)
oh.fit(train['Weight_Status'].values.reshape(-1,1))
temp = oh.transform(train['Weight_Status'].values.reshape(-1,1))
temp = pd.DataFrame(temp, columns=['Normal', 'Obese', 'OverWeight'])
train = pd.concat([train, temp], axis=1)

temp = oh.transform(test['Weight_Status'].values.reshape(-1,1))
temp = pd.DataFrame(temp, columns=['Normal', 'Obese', 'OverWeight'])
test = pd.concat([test, temp], axis=1)

# %% [markdown]
# ## Gender

# %%
train['Gender'] = train['Gender'].replace(['F','M'], [0, 1])
test['Gender'] = test['Gender'].replace(['F','M'], [0, 1])

# %% [markdown]
# ## 파생변수 (기초대사량)

# %%
min_ex = min(train['Exercise_Duration'])
max_ex = max(train['Exercise_Duration'])
ex_range = max_ex- min_ex
# min_ex, max_ex, ex_range
train['Exercise_gubun'] = pd.cut(train['Exercise_Duration'], [0, min_ex+(0.2*ex_range), min_ex+(0.4*ex_range), min_ex+(0.6*ex_range), min_ex+(0.8*ex_range), max_ex+10])
train['Exercise_gubun'] = train['Exercise_gubun'].astype('category').cat.codes

test['Exercise_gubun'] = pd.cut(test['Exercise_Duration'], [0, min_ex+(0.2*ex_range), min_ex+(0.4*ex_range), min_ex+(0.6*ex_range), min_ex+(0.8*ex_range), max_ex+10])
test['Exercise_gubun'] = test['Exercise_gubun'].astype('category').cat.codes

train['Exercise_gubun'].value_counts()
# Out:
# 1    1572
# 2    1557
# 3    1518
# 4    1435
# 0    1418
# Name: Exercise_gubun, dtype: int64

# %%
# 기초대사량 계산 Harris Benedict (해리스 베네딕트 방정식)
# 남자: 66.5 + (13.75 X 체중 kg) + (5.003 X 키 cm) - (6.75 X 나이)
# 여자: 655.1 + (9.563 X 체중 kg) + (1.850 X 키 cm) - (4.676 X 나이)

train['harris'] = np.where(train['Gender']==0, 655.1 + (9.563*train['Weight(kg)']) + (185 * train['Height(m)'])-(4.676*train['Age'])
                           , 66.5 + (13.75*train['Weight(kg)']) + (500.3 * train['Height(m)'])-(6.75*train['Age']))
test['harris'] = np.where(test['Gender']==0, 655.1 + (9.563*test['Weight(kg)']) + (185 * test['Height(m)'])-(4.676*test['Age'])
                           , 66.5 + (13.75*test['Weight(kg)']) + (500.3 * test['Height(m)'])-(6.75*test['Age']))

# %%
# 좌식(운동을 거의 또는 전혀 하지 않음): calories = BMR × 1.2;
# 가벼운 활동(가벼운 운동/스포츠 1-3일/주): calories = BMR × 1.375;
# 적당히 활동적(중간 정도의 운동/스포츠 3-5일/주): calories = BMR × 1.55;
# 매우 활동적(일주일에 6-7일 격렬한 운동/스포츠): calories = BMR × 1.725; 그리고
# 매우 활동적인 경우(매우 힘든 운동/스포츠 및 육체노동): calories = BMR × 1.9.

exidx = train[train['Exercise_gubun']==0].index
train.loc[exidx, 'harris'] = train.loc[exidx, 'harris']*1.2
exidx = train[train['Exercise_gubun']==1].index
train.loc[exidx, 'harris'] = train.loc[exidx, 'harris']*1.375
exidx = train[train['Exercise_gubun']==2].index
train.loc[exidx, 'harris'] = train.loc[exidx, 'harris']*1.55
exidx = train[train['Exercise_gubun']==3].index
train.loc[exidx, 'harris'] = train.loc[exidx, 'harris']*1.725
exidx = train[train['Exercise_gubun']==4].index
train.loc[exidx, 'harris'] = train.loc[exidx, 'harris']*1.9

exidx = test[test['Exercise_gubun']==0].index
test.loc[exidx, 'harris'] = test.loc[exidx, 'harris']*1.2
exidx = test[test['Exercise_gubun']==1].index
test.loc[exidx, 'harris'] = test.loc[exidx, 'harris']*1.375
exidx = test[test['Exercise_gubun']==2].index
test.loc[exidx, 'harris'] = test.loc[exidx, 'harris']*1.55
exidx = test[test['Exercise_gubun']==3].index
test.loc[exidx, 'harris'] = test.loc[exidx, 'harris']*1.725
exidx = test[test['Exercise_gubun']==4].index
test.loc[exidx, 'harris'] = test.loc[exidx, 'harris']*1.9

# %%
print(train[['harris','Calories_Burned']].corr())
sns.lmplot(train, x = 'harris', y='Calories_Burned')
plt.show()
# Out:
#                    harris  Calories_Burned
# harris           1.000000         0.579066
# Calories_Burned  0.579066         1.000000

# %% [markdown]
# ## 상관관계

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(train.corr(), fmt='.2f',annot=True)
plt.show()

# %%
train.columns
# Out:
# Index(['Exercise_Duration', 'Body_Temperature(F)', 'BPM', 'Height(Feet)',
#        'Height(Remainder_Inches)', 'Weight(lb)', 'Weight_Status', 'Gender',
#        'Age', 'Calories_Burned', 'Height(Inches)', 'Height(m)', 'Weight(kg)',
#        'bmi', 'Normal', 'Obese', 'OverWeight', 'Exercise_gubun', 'harris'],
#       dtype='object')

# %% [markdown]
# # 학습 및 검증

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler

# from catboost import CatBoostRegressor
# import catboost as cb
# from xgboost import XGBRegressor

# %%
# col_list = ['Exercise_Duration', 'Body_Temperature(F)', 'BPM', 'Weight(lb)', 'Gender', 'Age',  'Height(Inches)',
#        'bmi', 'Normal', 'Obese', 'OverWeight']  

# ss = StandardScaler()

# trainX = train[col_list]
# ss.fit(trainX)
# trainX = ss.transform(trainX)

# trainy = train['Calories_Burned']
# trainy = np.log1p(trainy)

# testX = test[col_list]
# testX = ss.transform(testX)

# model = CatBoostRegressor(random_seed=11, loss_function='RMSE')

# kf = KFold(n_splits=5, shuffle=True, random_state=11)
# score_list = cross_val_score(model, trainX, trainy, scoring='neg_root_mean_squared_error', cv=kf)
# print(f'scroe {-np.mean(score_list)}')

# model.fit(trainX, trainy,  verbose=False)
# pred = model.predict(testX)

# pred = np.expm1(pred)

# result = pd.read_csv('./datasets/sample_submission.csv')
# result['Calories_Burned'] = pred
# result.to_csv('./submit_v3.csv', index=False)

# %% [markdown]
# # AutoML

# %%
# !pip install mljar-supervised
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mljar-supervised
#   Downloading mljar-supervised-0.11.5.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.22.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.5.3)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.2.2)
# Requirement already satisfied: xgboost>=1.3.3 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.7.5)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (3.3.5)
# Collecting catboost>=0.24.4
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.2.0)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (0.8.10)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (3.7.1)
# Collecting dtreeviz>=2.0.0
#   Downloading dtreeviz-2.2.1-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.5/91.5 kB 10.0 MB/s eta 0:00:00
# Collecting shap>=0.36.0
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 kB 31.9 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (0.12.2)
# Requirement already satisfied: wordcloud>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.8.2.2)
# Collecting category_encoders>=2.2.2
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 9.2 MB/s eta 0:00:00
# Collecting optuna>=2.7.0
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 26.7 MB/s eta 0:00:00
# Collecting scikit-plot==0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (3.4.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (4.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (1.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (5.13.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (0.20.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category_encoders>=2.2.2->mljar-supervised) (0.5.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders>=2.2.2->mljar-supervised) (0.13.5)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from dtreeviz>=2.0.0->mljar-supervised) (7.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->mljar-supervised) (0.40.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (3.0.9)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.3-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 19.1 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (2.0.9)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (4.65.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->mljar-supervised) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0->mljar-supervised) (3.1.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap>=0.36.0->mljar-supervised) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from shap>=0.36.0->mljar-supervised) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->mljar-supervised) (6.4.1)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown->mljar-supervised) (3.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna>=2.7.0->mljar-supervised) (2.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->shap>=0.36.0->mljar-supervised) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap>=0.36.0->mljar-supervised) (0.39.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost>=0.24.4->mljar-supervised) (8.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (1.1.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (2.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (23.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (1.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna>=2.7.0->mljar-supervised) (2.1.2)
# Building wheels for collected packages: mljar-supervised
#   Building wheel for mljar-supervised (setup.py) ... done
#   Created wheel for mljar-supervised: filename=mljar_supervised-0.11.5-py3-none-any.whl size=147060 sha256=2a7c17b22332baca22aede855c893235001a5740b9f59a31b3f9f8e74e4482d7
#   Stored in directory: /root/.cache/pip/wheels/62/ed/f2/9a70a649613cf977a8b1e39ce373d14290a135fa309c1f1638
# Successfully built mljar-supervised
# Installing collected packages: colour, slicer, Mako, colorlog, cmaes, alembic, shap, scikit-plot, optuna, dtreeviz, catboost, category_encoders, mljar-supervised
# Successfully installed Mako-1.2.4 alembic-1.10.3 catboost-1.1.1 category_encoders-2.6.0 cmaes-0.9.1 colorlog-6.7.0 colour-0.1.5 dtreeviz-2.2.1 mljar-supervised-0.11.5 optuna-3.1.1 scikit-plot-0.3.7 shap-0.41.0 slicer-0.0.7

# %%
import random
import os

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(222) # Seed 고정

# %%
import os

from supervised.automl import AutoML

col_list = ['Exercise_Duration', 'Body_Temperature(F)', 'BPM', 'Weight(kg)', 'Gender', 'Age',  'Height(m)', 'bmi', 'harris']  


trainy = train['Calories_Burned']
trainy = np.log1p(trainy)


trainX = train[col_list]
trainX = np.log1p(trainX)

testX = test[col_list]
testX = np.log1p(testX)

automl = AutoML(mode="Compete", eval_metric='rmse')

automl.fit(trainX, trainy)

y_pred = automl.predict(testX)

y_pred = np.expm1(y_pred)

result = pd.read_csv('/content/drive/MyDrive/핀테크_강의/Competition/CAL_CONSUM/datasets/sample_submission.csv')
result['Calories_Burned'] = y_pred
result.to_csv('/content/drive/MyDrive/핀테크_강의/Competition/CAL_CONSUM/datasets/submit_v3.csv', index=False)
# Out:
# AutoML directory: AutoML_1
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree rmse 0.228774 trained in 0.87 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 4 models
# 1_DecisionTree rmse 0.239187 trained in 2.92 seconds
# 2_DecisionTree rmse 0.198141 trained in 2.81 seconds
# 3_DecisionTree rmse 0.198141 trained in 3.55 seconds
# 4_Linear rmse 0.097304 trained in 3.78 seconds
# * Step default_algorithms will try to check up to 7 models
# 5_Default_LightGBM rmse 0.032582 trained in 47.9 seconds
# 6_Default_Xgboost rmse 0.030891 trained in 27.06 seconds
# 7_Default_CatBoost rmse 0.019926 trained in 39.98 seconds
# 8_Default_NeuralNetwork rmse 0.024749 trained in 17.4 seconds
# 9_Default_RandomForest rmse 0.171252 trained in 25.43 seconds
# 10_Default_ExtraTrees rmse 0.180275 trained in 17.62 seconds
# There was an error during 11_Default_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# * Step not_so_random will try to check up to 63 models
# 20_LightGBM rmse 0.025456 trained in 37.87 seconds
# 11_Xgboost rmse 0.033532 trained in 19.43 seconds
# 29_CatBoost rmse 0.021918 trained in 102.57 seconds
# 38_RandomForest rmse 0.169711 trained in 23.46 seconds
# 47_ExtraTrees rmse 0.23987 trained in 14.33 seconds
# 56_NeuralNetwork rmse 0.027467 trained in 12.48 seconds
# There was an error during 65_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 21_LightGBM rmse 0.040854 trained in 20.58 seconds
# 12_Xgboost rmse 0.034968 trained in 38.03 seconds
# 30_CatBoost rmse 0.027359 trained in 52.26 seconds
# 39_RandomForest rmse 0.196964 trained in 15.12 seconds
# 48_ExtraTrees rmse 0.230422 trained in 15.13 seconds
# 57_NeuralNetwork rmse 0.02515 trained in 20.16 seconds
# There was an error during 66_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 22_LightGBM rmse 0.031097 trained in 42.8 seconds
# 13_Xgboost rmse 0.03672 trained in 35.25 seconds
# 31_CatBoost rmse 0.020796 trained in 54.45 seconds
# 40_RandomForest rmse 0.112244 trained in 37.2 seconds
# 49_ExtraTrees rmse 0.135417 trained in 20.68 seconds
# 58_NeuralNetwork rmse 0.028524 trained in 30.01 seconds
# There was an error during 67_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 23_LightGBM rmse 0.034428 trained in 39.83 seconds
# 14_Xgboost rmse 0.036677 trained in 22.13 seconds
# 32_CatBoost rmse 0.031414 trained in 37.92 seconds
# 41_RandomForest rmse 0.115737 trained in 28.69 seconds
# 50_ExtraTrees rmse 0.146051 trained in 19.4 seconds
# 59_NeuralNetwork rmse 0.025765 trained in 20.95 seconds
# There was an error during 68_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 24_LightGBM rmse 0.037339 trained in 29.8 seconds
# 15_Xgboost rmse 0.032263 trained in 28.78 seconds
# 33_CatBoost rmse 0.025316 trained in 56.42 seconds
# 42_RandomForest rmse 0.094276 trained in 32.49 seconds
# 51_ExtraTrees rmse 0.123932 trained in 22.22 seconds
# 60_NeuralNetwork rmse 0.025001 trained in 25.3 seconds
# There was an error during 69_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 25_LightGBM rmse 0.040208 trained in 101.1 seconds
# 16_Xgboost rmse 0.028083 trained in 24.53 seconds
# 34_CatBoost rmse 0.02396 trained in 49.72 seconds
# 43_RandomForest rmse 0.094272 trained in 47.71 seconds
# 52_ExtraTrees rmse 0.116401 trained in 27.61 seconds
# 61_NeuralNetwork rmse 0.026279 trained in 23.82 seconds
# There was an error during 70_NearestNeighbors training.
# Please check AutoML_1/errors.md for details.
# 26_LightGBM rmse 0.031881 trained in 57.07 seconds
# 17_Xgboost rmse 0.030229 trained in 36.15 seconds
# 35_CatBoost rmse 0.02375 trained in 161.33 seconds
# 44_RandomForest rmse 0.164801 trained in 23.76 seconds
# 53_ExtraTrees rmse 0.187114 trained in 25.04 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: BPM_sum_Exercise_Duration
# Add Golden Feature: BPM_multiply_Exercise_Duration
# Add Golden Feature: Exercise_Duration_diff_Body_Temperature(F)
# Add Golden Feature: Exercise_Duration_ratio_Body_Temperature(F)
# Add Golden Feature: Body_Temperature(F)_ratio_Exercise_Duration
# Add Golden Feature: Body_Temperature(F)_sum_Exercise_Duration
# Add Golden Feature: Body_Temperature(F)_multiply_Exercise_Duration
# Add Golden Feature: bmi_multiply_Exercise_Duration
# Add Golden Feature: Exercise_Duration_diff_Height(m)
# Add Golden Feature: bmi_sum_Exercise_Duration
# Created 10 Golden Features in 13.36 seconds.
# 7_Default_CatBoost_GoldenFeatures rmse 0.020499 trained in 130.66 seconds
# * Step kmeans_features will try to check up to 3 models
# 7_Default_CatBoost_KMeansFeatures rmse 0.023454 trained in 128.46 seconds
# * Step insert_random_feature will try to check up to 1 model
# 7_Default_CatBoost_RandomFeature rmse 0.01986 trained in 53.62 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 32 models
# 62_CatBoost rmse 0.019027 trained in 40.48 seconds
# 63_CatBoost rmse 0.022201 trained in 55.29 seconds
# 64_CatBoost_GoldenFeatures rmse 0.019752 trained in 89.15 seconds
# 65_CatBoost_GoldenFeatures rmse 0.021574 trained in 167.94 seconds
# 66_CatBoost rmse 0.019882 trained in 50.4 seconds
# 67_CatBoost rmse 0.022989 trained in 79.52 seconds
# * Step hill_climbing_2 will try to check up to 24 models
# 68_CatBoost rmse 0.023664 trained in 53.92 seconds
# 69_CatBoost_GoldenFeatures rmse 0.024798 trained in 88.69 seconds
# 70_CatBoost rmse 0.024277 trained in 49.36 seconds
# 71_NeuralNetwork rmse 0.026251 trained in 26.52 seconds
# 72_NeuralNetwork rmse 0.028988 trained in 25.17 seconds
# 73_NeuralNetwork rmse 0.025863 trained in 23.58 seconds
# * Step boost_on_errors will try to check up to 1 model
# 62_CatBoost_BoostOnErrors rmse 0.018872 trained in 39.61 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 0.017167 trained in 14.36 seconds
# * Step stack will try to check up to 51 models
# 62_CatBoost_Stacked rmse 0.023114 trained in 240.89 seconds
# 8_Default_NeuralNetwork_Stacked rmse 0.312461 trained in 37.79 seconds
# 20_LightGBM_Stacked rmse 0.024774 trained in 26.17 seconds
# 16_Xgboost_Stacked rmse 0.024328 trained in 21.52 seconds
# 43_RandomForest_Stacked rmse 0.019008 trained in 283.41 seconds
# 52_ExtraTrees_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 4.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 64_CatBoost_GoldenFeatures_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 31.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked rmse 0.016559 trained in 16.33 seconds
# AutoML fit time: 3653.28 seconds
# AutoML best model: Ensemble_Stacked

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
